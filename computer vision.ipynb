# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [raw]
# import cv2

# %%
import cv2

# %%
img = cv2.imread("mushroom.jpg")
#upload the image

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img_wrong = cv2.imread('wrong/path/hfkjshfk.jpg')
#it gives you the chance but it does not translate into anything

# %%
type(img_wrong)
# Out:
# NoneType

# %%
plt.imshow(img)

# %%
img_gray = cv2.imread('mushroom.jpg', cv2.IMREAD_GRAYSCALE)
img_gray.shape
#we can modify our image
# Out:
# (191, 264)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap="gray")

# %%
img_gray.shape
# Out:
# (191, 264)

# %%
fix_img =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (191, 264, 3)

# %%
new_img =cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (400, 1000, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

new_img=cv2.resize(fix_img,(0,0), fix_img, w_ratio,h_ratio)

# %%
flip_img= cv2.flip(fix_img, 0)
#this way we can flip the image

# %%
plt.imshow(flip_img)

# %%
flip_img2= cv2.flip(fix_img, 1)
plt.imshow(flip_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('mushroom.jpg', fix_img)
# Out:
# True

# %%
img2= cv2.cvtColor(img,cv2.COLOR_BGR2HSV)

# %%
plt.imshow(img2)

# %%
img3= cv2.cvtColor(img,cv2.COLOR_BGR2HLS)

# %%
plt.imshow(img3)

# %%
img1 =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
img1 = cv2.imread('dnc.jpg')
img2 = cv2.imread('mushroom.jpg')

# %%
plt.imshow(img3)

# %%
plt.imshow(img1)

# %%
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
#we created two archives for merching both images

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1 = cv2.resize(img1,(1200,1200))
img2 = cv2.resize(img2,(1200,1200))

# %%
alpha =0.5
beta= 0.5

# %%
blended = cv2.addWeighted(img1, alpha, img2,beta, gamma=0)

# %%
plt.imshow(blended)

# %%
alpha = 0.8
beta = 0.2

blended1= cv2.addWeighted(img1, alpha, img2, beta, 0)
plt.imshow(blended1)
# by m,odifying alpha and beta one is superposed on aother one

# %%
img1= cv2.imread('dnc.jpg')
img2= cv2.imread('mushroom.jpg')

img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
img1 = cv2.resize(img1, (100,100))

# %%
# we can also show both in different sizes
large_img = img2
small_img = img1

x_offset= 0
y_offset= 0

x_end = x_offset + small_img.shape[1]
y_end =  y_offset + small_img.shape[0]

large_img[y_offset:y_end, x_offset:x_end] =small_img

plt.imshow(large_img)

# %%
# download the archives
img= cv2.imread('rainbow.jpg')

# %%
plt.imshow(img)

# %%
img=cv2.imread('rainbow.jpg', 0)

# %%
#gray scale
plt.imshow(img, cmap= 'gray')

# %%
ret, thresh1= cv2.threshold(img, 127,255,cv2.THRESH_BINARY)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1, cmap= "gray")

# %%
# we can modify the image in order to really apreciate the details of what we are observing
img2= cv2.imread('rainbow.jpg', 0)
ret, thresh1= cv2.threshold(img2, 127,255, cv2.THRESH_TRUNC)
plt.imshow(thresh1, cmap="gray")

# %%
img3= cv2.imread('rainbow.jpg', 0)
ret, thresh1= cv2.threshold(img2, 127,255, cv2.THRESH_TOZERO)
plt.imshow(thresh1, cmap="gray")

# %%
img_r = cv2.imread('crossword.jpg', 0)
plt.imshow(img_r, cmap='gray')

# %%
def show_pic(img): 
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap = 'gray')

# %%
ret, th1 = cv2.threshold(img_r, 127,255, cv2.THRESH_BINARY)
show_pic(th1)
#this way we are going to take the gray parts and turn them white

# %%
ret, th1 = cv2.threshold(img_r, 200,255, cv2.THRESH_BINARY)
show_pic(th1)

# %%
th2 = cv2.adaptiveThreshold(img_r,255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,11,8)
# you can choose the theshold types and the back size is amplified

# %%
show_pic(th2)

# %%
blended = cv2.addWeighted(src1= th1, alpha=0.6,
                          src2= th2, beta = 0.4, gamma = 0 )
show_pic(blended)

# %%
th3 = cv2.adaptiveThreshold(img_r, 255, cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY, 11,8)
blended = cv2.addWeighted(src1= th1, alpha= 0.6,
                          src2= th3, beta=0.4,gamma=0)
show_pic(blended)
